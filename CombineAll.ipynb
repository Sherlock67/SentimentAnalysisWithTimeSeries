# %%
import os
import glob
import pandas as pd
os.chdir(r"C:\Users\admin\Desktop\New folder")

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
print(all_filenames)
# Out:
# ['1.csv', '10.csv', '11.csv', '12.csv', '13.csv', '14.csv', '15.csv', '16.csv', '17.csv', '18.csv', '19.csv', '2.csv', '20.csv', '21.csv', '22.csv', '23.csv', '3.csv', '4.csv', '5.csv', '6.csv', '7.csv', '8.csv', '9.csv']

# %%
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
print(combined_csv)
combined_csv.to_csv( "The DataSet.csv", index=False, encoding='utf-8-sig')
# Out:
#       Unnamed: 0     screen_name  \
# 0            0.0   TheBizJournal
# 1            1.0         lilo623
# 2            2.0     PtzNoticias
# 3            3.0        ZonaDocs
# 4            4.0    frankedson24
# ...          ...             ...
# 4137      4137.0     GetsGreased
# 4138      4138.0           Grav1
# 4139      4139.0  Twofoxstudios1
# 4140      4140.0  FatimaLandMary
# 4141      4141.0      germbuffer
#
#                                               username       user_id  \
# 0     The Business Journal | Youngstown Publishing Co.  3.145505e+08
# 1                                  Linda Marie Lovison  8.839464e+07
# 2                                   Pátzcuaro Noticias  9.910357e+17
# 3                                             ZonaDocs  1.030901e+18
# 4                                                Frank  3.014628e+09
# ...                                                ...           ...
# 4137                                     Squeaky Wheel  2.081946e+07
# ...

# %%
import pandas as pd
data = pd.read_csv('New Text Document.txt',sep= " ",header = None, error_bad_lines=False)
print(data)
data.to_csv('100.csv')
# Out:
#              0                       1            2   \
# 0   {'tweetId':  '1275036802521403393',  'tweetUrl':
# 1   {'tweetId':  '1272536875555860485',  'tweetUrl':
# 2   {'tweetId':  '1244529004935360513',  'tweetUrl':
# 3   {'tweetId':  '1275036802521403393',  'tweetUrl':
# 4   {'tweetId':  '1272536875555860485',  'tweetUrl':
# 5   {'tweetId':  '1244529004935360513',  'tweetUrl':
# 6   {'tweetId':  '1275036802521403393',  'tweetUrl':
# 7   {'tweetId':  '1272536875555860485',  'tweetUrl':
# 8   {'tweetId':  '1244529004935360513',  'tweetUrl':
# 9   {'tweetId':  '1275036802521403393',  'tweetUrl':
# 10  {'tweetId':  '1272536875555860485',  'tweetUrl':
# 11  {'tweetId':  '1244529004935360513',  'tweetUrl':
# 12  {'tweetId':  '1275036802521403393',  'tweetUrl':
# 13  {'tweetId':  '1272536875555860485',  'tweetUrl':
# 14  {'tweetId':  '1244529004935360513',  'tweetUrl':
# 15  {'tweetId':  '1275036802521403393',  'tweetUrl':
# 16  {'tweetId':  '1272536875555860485',  'tweetUrl':
# ...

# %%
pip install twarc
# Out:
# ...
#   Created wheel for twarc: filename=twarc-1.10.1-py3-none-any.whl size=24464 sha256=8d61328d03594a5175fc3547ae1cd61299c45ec29ae97c44d410074fa7833022
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\df\29\53\4dc1f0b611523c2046ee5ed94e4e910a1a1175f6c3fc169ee9
# Successfully built twarc
# ...
